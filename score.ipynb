# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
import re
from PIL import Image
import shutil
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt
from glob import glob
import pandas as pd
from tqdm import tqdm

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# %%
path ='/content/drive/MyDrive/growth/open/'
train_score = pd.read_csv(path + 'train_score.csv')
test_score = pd.read_csv(path + 'test_score.csv')
submission = pd.read_csv('/content/drive/MyDrive/growth/open/sample_submission.csv')

# %%
train_bc = train_score[train_score['species'] == 'bc']
train_lt = train_score[train_score['species'] == 'lt']
test_bc = test_score[test_score['species'] == 'bc']
test_lt = test_score[test_score['species'] == 'lt']

# %%
train_bc
# Out:
#       Unnamed: 0                                   before_file_path  \
# 0              0  /content/drive/MyDrive/growth/open/train_datas...
# 1              1  /content/drive/MyDrive/growth/open/train_datas...
# 2              2  /content/drive/MyDrive/growth/open/train_datas...
# 3              3  /content/drive/MyDrive/growth/open/train_datas...
# 4              4  /content/drive/MyDrive/growth/open/train_datas...
# ...          ...                                                ...
# 6807        6807  /content/drive/MyDrive/growth/open/train_datas...
# 6808        6808  /content/drive/MyDrive/growth/open/train_datas...
# 6809        6809  /content/drive/MyDrive/growth/open/train_datas...
# 6810        6810  /content/drive/MyDrive/growth/open/train_datas...
# 6811        6811  /content/drive/MyDrive/growth/open/train_datas...
#
#                                         after_file_path  time_delta species  \
# ...

# %%
train_bc

# %%
test_score
# Out:
#                                         before_file_path  \
# 0      /content/drive/MyDrive/growth/open/test_datase...
# 1      /content/drive/MyDrive/growth/open/test_datase...
# 2      /content/drive/MyDrive/growth/open/test_datase...
# 3      /content/drive/MyDrive/growth/open/test_datase...
# 4      /content/drive/MyDrive/growth/open/test_datase...
# ...                                                  ...
# 16648  /content/drive/MyDrive/growth/open/test_datase...
# 16649  /content/drive/MyDrive/growth/open/test_datase...
# 16650  /content/drive/MyDrive/growth/open/test_datase...
# 16651  /content/drive/MyDrive/growth/open/test_datase...
# 16652  /content/drive/MyDrive/growth/open/test_datase...
#
#                                          after_file_path  time_delta species  \
# 0      /content/drive/MyDrive/growth/open/test_datase...          20      bc
# 1      /content/drive/MyDrive/growth/open/test_datase...          26      bc
# ...

# %%
submission['time_delta'] = test_score['time_delta']

# %%
submission.to_csv(path + 'idontknow.csv', index=False)
